# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %%
#song_files = get_files('data/song_data')
#filepath = song_files[0]
#df_song = pd.read_json(filepath, lines=True)
song_files = get_files('data/song_data')
for i in range(len(song_files)):
    filepath = song_files[i]
    #print(filepath)
    df_b = pd.read_json(filepath, lines=True)
    df_song = pd.concat([df_song, df_b])
    #print(filepath)

# %%
df_song.drop_duplicates()
# Out:
#              artist_id  artist_latitude              artist_location  \
# 0   ARD7TVE1187B99BFB1              NaN              California - LA
# 0   ARNTLGG11E2835DDB9              NaN
# 0   AR8ZCNI1187B9A069B              NaN
# 0   AR10USD1187B99F3F1              NaN  Burlington, Ontario, Canada
# 0   ARMJAGH1187FB546F3         35.14968                  Memphis, TN
# 0   ARKFYS91187B98E58F              NaN
# 0   ARD0S291187B9B7BF5              NaN                         Ohio
# 0   ARGSJW91187B9B1D6B         35.21962               North Carolina
# 0   AR7G5I41187FB4CE6C              NaN              London, England
# 0   ARXR32B1187FB57099              NaN
# 0   ARKRRTF1187B9984DA              NaN
# 0   ARIG6O41187B988BDD         37.16793                United States
# 0   AR1ZHYZ1187FB3C717              NaN
# 0   ARD842G1187B997376         43.64856     Toronto, Ontario, Canada
# 0   ARL7K851187B99ACD2              NaN
# 0   ARHHO3O1187B989413              NaN
# ...

# %%
df_song.query('duration == 236.93016')
# Out:
#             artist_id  artist_latitude          artist_location  \
# 0  AR9AWNF1187B9AB0B4              NaN  Seattle, Washington USA
# 0  AR9AWNF1187B9AB0B4              NaN  Seattle, Washington USA
#
#    artist_longitude                   artist_name   duration  num_songs  \
# 0               NaN  Kenny G featuring Daryl Hall  236.93016          1
# 0               NaN  Kenny G featuring Daryl Hall  236.93016          1
#
#               song_id            title  year
# 0  SOZHPGD12A8C1394FE  Baby Come To Me     0
# 0  SOZHPGD12A8C1394FE  Baby Come To Me     0

# %%
duration_list = df_song.duration.tolist()

# %%
#AS i got an error in building the song_plays table i found out that the duration did not exist in my log file. So i had to iterate through and find the right data log.
filepath = '/home/workspace/data/log_data/2018/11/2018-11-30-events.json'
df_log = pd.read_json(filepath, lines=True)

log_files = get_files('data/log_data')
for i in range(len(log_files)):
    filepath = log_files[i]
    #print(filepath)
    df_b = pd.read_json(filepath, lines=True)
    pd.concat([df_log, df_b])
    #print(filepath)
df_log
#df_log.query('song == 218.93179')
# Out:
#                                       artist        auth firstName gender  \
# 0                              Stephen Lynch   Logged In    Jayden      M
# 1                                    Manowar   Logged In     Jacob      M
# 2                                  Morcheeba   Logged In     Jacob      M
# 3                                   Maroon 5   Logged In     Jacob      M
# 4                                      Train   Logged In     Jacob      M
# 5                                      LMFAO   Logged In     Jacob      M
# 6                                   DJ Dizzy   Logged In     Jacob      M
# 7                    Fish Go Deep & Tracey K   Logged In     Jacob      M
# 8                                       None   Logged In    Alivia      F
# 9                                        M83   Logged In     Jacob      M
# 10                                    Saybia   Logged In     Jacob      M
# 11                             Local Natives   Logged In     Jacob      M
# ...

# %%
df_log.query('length == 236.93016')
# Out:
#            artist       auth firstName gender  itemInSession lastName  \
# 276  Jack Johnson  Logged In     Rylan      M              9   George
#
#         length level               location method      page  registration  \
# 276  236.93016  paid  Birmingham-Hoover, AL    PUT  NextSong  1.541020e+12
#
#      sessionId         song  status             ts  \
# 276       1076  Bubble Toes     200  1543591138796
#
#                                              userAgent userId
# 276  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16

# %%
display(df_song.columns)
display(df_log.columns)
# Out:
# Index(['artist_id', 'artist_latitude', 'artist_location', 'artist_longitude',
#        'artist_name', 'duration', 'num_songs', 'song_id', 'title', 'year'],
#       dtype='object')
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %%
for i in duration_list:
    print(df_log.loc[df_log['length'] == i])
# Out:
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# ...

# %%
log_files = get_files('data/log_data')
for i in range(len(log_files)):
    filepath = log_files[i]
    print(filepath)
    df_log = pd.read_json(filepath, lines=True)
    print(filepath)
    display(df_log[df_log['length'] == 236.93016])
# Out:
# /home/workspace/data/log_data/2018/11/2018-11-30-events.json
# /home/workspace/data/log_data/2018/11/2018-11-30-events.json
#            artist       auth firstName gender  itemInSession lastName  \
# 276  Jack Johnson  Logged In     Rylan      M              9   George
#
#         length level               location method      page  registration  \
# 276  236.93016  paid  Birmingham-Hoover, AL    PUT  NextSong  1.541020e+12
#
#      sessionId         song  status             ts  \
# 276       1076  Bubble Toes     200  1543591138796
#
#                                              userAgent userId
# 276  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# /home/workspace/data/log_data/2018/11/2018-11-11-events.json
# /home/workspace/data/log_data/2018/11/2018-11-11-events.json
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []
# ...

# %%
song_files = get_files('data/song_data')
for i in range(len(song_files)):
    filepath = song_files[i]
    print(filepath)
    df_log = pd.read_json(filepath, lines=True)
    print(filepath)
    display(df_song[df_song['duration'] == 236.93016])
# Out:
# /home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json
# /home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json
#             artist_id  artist_latitude          artist_location  \
# 0  AR9AWNF1187B9AB0B4              NaN  Seattle, Washington USA
# 0  AR9AWNF1187B9AB0B4              NaN  Seattle, Washington USA
#
#    artist_longitude                   artist_name   duration  num_songs  \
# 0               NaN  Kenny G featuring Daryl Hall  236.93016          1
# 0               NaN  Kenny G featuring Daryl Hall  236.93016          1
#
#               song_id            title  year
# 0  SOZHPGD12A8C1394FE  Baby Come To Me     0
# 0  SOZHPGD12A8C1394FE  Baby Come To Me     0
# /home/workspace/data/song_data/A/A/A/TRAAAVG12903CFA543.json
# /home/workspace/data/song_data/A/A/A/TRAAAVG12903CFA543.json
#             artist_id  artist_latitude          artist_location  \
# 0  AR9AWNF1187B9AB0B4              NaN  Seattle, Washington USA
# ...

# %%
test_duration = (df_song.values[0,5])

df_log.loc[df_log['length'] == test_duration]
#df_log.loc[df_log['length'] == 182.85669]

# %%
#AS i got an error in building the song_plays table i found out that the duration did not exist in my log file. So i had to iterate through and find the right data log.
filepath = '/home/workspace/data/log_data/2018/11/2018-11-30-events.json'
df_log = pd.read_json(filepath, lines=True)

log_files = get_files('data/log_data')
for i in range(len(log_files)):
    filepath = log_files[i]
    #print(filepath)
    df_b = pd.read_json(filepath, lines=True)
    pd.concat([df_log, df_b])
    print(filepath)

df_log.query('song == 218.93179')

# %%
log_files = get_files('data/log_data')
for i in range(len(log_files)):
    filepath = log_files[i]
    print(filepath)
    df_log = pd.read_json(filepath, lines=True)
    print(filepath)
    display(df_log[df_log['length'] == 236.93016])
